# %%
import numpy as np
import pandas as pd
import mysql.connector
import re

# %%
try:
    with open('user_pass.txt', 'r') as fp:
        lines = fp.readlines()

    user = lines[0].split('\"')[-2]
    password = lines[1].split('\"')[-2]
except:
    print("""The User Pass format should be like:
            user = "myUser"
            pass =  "myPassword"  
            """)

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = f"{user}",
    password = f"{password}",
)

# %%
mycursor = db.cursor()

# %%
SQL_queries = ["DROP DATABASE IF EXISTS `IMDB_Movies`;"
        , "CREATE DATABASE `IMDB_Movies`;"
        , "USE `IMDB_Movies`;"
        , """CREATE TABLE Top250_Movies(
        movie_id int(4) NOT NULL AUTO_INCREMENT
        , Movie_Name varchar(100) NOT NULL
        , Year int(4) NOT NULL
        , IMDB_Rating float(4) NOT NULL
        , PRIMARY KEY (movie_id)
        ) ENGINE=InnoDB AUTO_INCREMENT=11 DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_0900_ai_ci;"""
        , "ALTER TABLE Top250_Movies AUTO_INCREMENT = 1;"]

for query in SQL_queries:
    mycursor.execute(query)

# %%
def load_csv(addr):
    return pd.read_csv(addr)

# %%
addr = r".\Top250_Movies_Info_cleaned.csv"
top250_df = load_csv(addr)
top250_df.tail(3)
# Out:
#                              Title  Year Certificate      Time  \
# 247     The Passion of Joan of Arc  1928           A  1h 50min
# 248  Sunrise: A Song of Two Humans  1927           A  1h 34min
# 249                    The General  1926           U   1h 7min
#
#                                 Genere  \
# 247  ['Biography', 'Drama', 'History']
# 248               ['Drama', 'Romance']
# 249  ['Action', 'Adventure', 'Comedy']
#
#                                                   plot  Rating   Voting  \
# 247  In 1431, Jeanne d'Arc is placed on trial on ch...     8.1  50000.0
# 248  A sophisticated urban woman seduces a farmer i...     8.1  49000.0
# 249  When Union spies steal an engineer's beloved l...     8.1  85000.0
#
#                                                  Stars  \
# 247  ['Maria Falconetti', 'Eugene Silvain', 'André ...
# 248  ["George O'Brien", 'Janet Gaynor', 'Margaret L...
# 249  ['Buster Keaton', 'Marion Mack', 'Glen Cavende...
#
#                                Directors  \
# 247              ['Carl Theodor Dreyer']
# 248                      ['F.W. Murnau']
# 249  ['Clyde Bruckman', 'Buster Keaton']
#
#                                                Writers  User reviews  \
# 247          ['Joseph Delteil', 'Carl Theodor Dreyer']           210
# 248  ['Carl Mayer', 'Hermann Sudermann', 'Katherine...           270
# 249  ['Buster Keaton', 'Clyde Bruckman', 'Al Boasbe...           311
#
#      Critic reviews  Metascore                                     URL  \
# 247             141  82.660465  https://www.imdb.com//title/tt0019254/
# 248             122  82.660465  https://www.imdb.com//title/tt0018455/
# 249             120  82.660465  https://www.imdb.com//title/tt0017925/
#
#      minutes
# 247    110.0
# 248     94.0
# 249     67.0

# %%
for ind, movie_Info in top250_df.iterrows():
    #print(movie_Info)
    title = movie_Info['Title']
    year = int(movie_Info['Year'])
    rating = movie_Info['Rating']
    title = title.replace('\'', '')
    query = f"INSERT INTO Top250_Movies (Movie_Name, Year, IMDB_Rating) VALUES ('{title}', '{year}', '{rating}')"
    #print(query)
    mycursor.execute(query)

# Make sure data is committed to the database
db.commit()

# %%
mycursor.execute("""SELECT *
FROM Top250_movies""")

y = []
for ind, x in enumerate(mycursor): 
    y.append(x)

table_df = pd.DataFrame(y, columns =mycursor.column_names)
table_df.head(10)
# Out:
#    movie_id                                     Movie_Name  Year  IMDB_Rating
# 0         1                       The Shawshank Redemption  1994          9.3
# 1         2                                  The Godfather  1972          9.2
# 2         3                                The Dark Knight  2008          9.0
# 3         4                         The Godfather: Part II  1974          9.0
# 4         5                                   12 Angry Men  1957          9.0
# 5         6  The Lord of the Rings: The Return of the King  2003          8.9
# 6         7                                   Pulp Fiction  1994          8.9
# 7         8                                Schindlers List  1993          8.9
# 8         9                                      Inception  2010          8.8
# 9        10                                     Fight Club  1999          8.8
